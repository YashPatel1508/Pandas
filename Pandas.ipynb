# %% [markdown]
# <a href="https://colab.research.google.com/github/YashPatel1508/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Pandas CSV/pandas_practice_dataset_500_rows.csv") # Load CSV into pandas

# %%
df.head() #Show first 5 rows
# Out:
#    ID    Name  Age Gender       City  Salary Department  Experience_Years  \
# 0   1  User_1   56   Male  Ahmedabad   76276    Finance              12.2
# 1   2  User_2   46   Male      Delhi   39541  Marketing              10.6
# 2   3  User_3   32   Male       Pune  114457         IT              18.4
# 3   4  User_4   60   Male  Ahmedabad  102310         IT              10.2
# 4   5  User_5   25   Male     Mumbai   64813      Sales              19.8
#
#     Join_Date  Performance_Score  Bonus  Projects_Completed Remote_Work  \
# 0  2018-01-01                  1   3092                  17         Yes
# 1  2018-01-02                  1  19514                  15          No
# 2  2018-01-03                  5   6242                   7         Yes
# 3  2018-01-04                  4   9549                  32          No
# 4  2018-01-05                  3   6185                  48         Yes
#
#    Training_Hours Promoted
# 0              54      Yes
# 1              38      Yes
# ...

# %%
df.tail() #Show last 5 rows
# Out:
#       ID      Name  Age  Gender       City  Salary Department  \
# 495  496  User_496   37    Male       Pune  143153         IT
# 496  497  User_497   41    Male     Mumbai   46589    Finance
# 497  498  User_498   29  Female     Mumbai   50015    Finance
# 498  499  User_499   52    Male  Ahmedabad   49009      Sales
# 499  500  User_500   50    Male     Mumbai  103309         HR
#
#      Experience_Years   Join_Date  Performance_Score  Bonus  \
# 495               5.2  2019-05-11                  3  17311
# 496               3.3  2019-05-12                  4   9566
# 497               7.3  2019-05-13                  5  12889
# 498               9.3  2019-05-14                  5  12254
# 499              15.1  2019-05-15                  2  12442
#
#      Projects_Completed Remote_Work  Training_Hours Promoted
# 495                   6         Yes               3      Yes
# 496                  27         Yes              62      Yes
# ...

# %%
df.shape # Shape of dataset
# Out:
# (500, 15)

# %%
df.columns # Column names list
# Out:
# Index(['ID', 'Name', 'Age', 'Gender', 'City', 'Salary', 'Department',
#        'Experience_Years', 'Join_Date', 'Performance_Score', 'Bonus',
#        'Projects_Completed', 'Remote_Work', 'Training_Hours', 'Promoted'],
#       dtype='object')

# %%
df.dtypes # Data types of all columns
# Out:
# ID                      int64
# Name                   object
# Age                     int64
# Gender                 object
# City                   object
# Salary                  int64
# Department             object
# Experience_Years      float64
# Join_Date              object
# Performance_Score       int64
# Bonus                   int64
# Projects_Completed      int64
# Remote_Work            object
# Training_Hours          int64
# Promoted               object
# dtype: object

# %%
df.info() # Basic info summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  500 non-null    int64
#  1   Name                500 non-null    object
#  2   Age                 500 non-null    int64
#  3   Gender              500 non-null    object
#  4   City                500 non-null    object
#  5   Salary              500 non-null    int64
#  6   Department          500 non-null    object
#  7   Experience_Years    500 non-null    float64
#  8   Join_Date           500 non-null    object
#  9   Performance_Score   500 non-null    int64
#  10  Bonus               500 non-null    int64
#  11  Projects_Completed  500 non-null    int64
#  12  Remote_Work         500 non-null    object
#  13  Training_Hours      500 non-null    int64
#  14  Promoted            500 non-null    object
# dtypes: float64(1), int64(7), object(7)
# ...

# %%
df.describe() # Statistical summary
# Out:
#                ID         Age         Salary  Experience_Years  \
# count  500.000000  500.000000     500.000000        500.000000
# mean   250.500000   41.278000   85128.094000         10.301600
# std    144.481833   13.389072   37716.865083          5.656893
# min      1.000000   18.000000   20526.000000          0.600000
# 25%    125.750000   30.000000   52358.750000          5.275000
# 50%    250.500000   42.000000   84763.000000         10.400000
# 75%    375.250000   52.000000  116538.750000         15.300000
# max    500.000000   64.000000  149972.000000         20.000000
#
#        Performance_Score         Bonus  Projects_Completed  Training_Hours
# count         500.000000    500.000000          500.000000      500.000000
# mean            3.052000  10496.266000           24.814000       50.176000
# std             1.428768   5410.505013           14.860858       28.789907
# min             1.000000   1025.000000            0.000000        0.000000
# ...

# %%
df["Age"] # select one coloum
df[["Age", "Salary"]] # select Multiple coloum
# Out:
#      Age  Salary
# 0     56   76276
# 1     46   39541
# 2     32  114457
# 3     60  102310
# 4     25   64813
# ..   ...     ...
# 495   37  143153
# 496   41   46589
# 497   29   50015
# 498   52   49009
# 499   50  103309
#
# [500 rows x 2 columns]

# %%
len(df) #Count Rows
# Out:
# 500

# %%
df["City"].unique() # Find Unique
# Out:
# array(['Ahmedabad', 'Delhi', 'Pune', 'Mumbai', 'Bangalore'], dtype=object)

# %%
df["Department"].nunique() # Count Unique
# Out:
# 5

# %%
df["Department"].value_counts() # Count Value
# Out:
# Department
# Sales        110
# HR           109
# IT           103
# Marketing     98
# Finance       80
# Name: count, dtype: int64

# %%
df.sort_values("Salary", ascending=True) # Sort Value ascending
# Out:
#       ID      Name  Age  Gender       City  Salary Department  \
# 467  468  User_468   43    Male  Bangalore   20526  Marketing
# 131  132  User_132   64    Male  Ahmedabad   20806  Marketing
# 319  320  User_320   44    Male  Ahmedabad   21007    Finance
# 329  330  User_330   36    Male  Bangalore   21435      Sales
# 248  249  User_249   57    Male       Pune   21591         IT
# ..   ...       ...  ...     ...        ...     ...        ...
# 471  472  User_472   53    Male  Bangalore  149478      Sales
# 482  483  User_483   36    Male  Ahmedabad  149749         HR
# 36    37   User_37   20  Female       Pune  149828    Finance
# 265  266  User_266   18  Female      Delhi  149839  Marketing
# 113  114  User_114   24    Male       Pune  149972    Finance
#
#      Experience_Years   Join_Date  Performance_Score  Bonus  \
# 467               3.7  2019-04-13                  1  18677
# 131              14.9  2018-05-12                  4  15823
# ...

# %%
df.sort_values("Salary", ascending=False) # Sort Value descending
# Out:
#       ID      Name  Age  Gender       City  Salary Department  \
# 113  114  User_114   24    Male       Pune  149972    Finance
# 265  266  User_266   18  Female      Delhi  149839  Marketing
# 36    37   User_37   20  Female       Pune  149828    Finance
# 482  483  User_483   36    Male  Ahmedabad  149749         HR
# 471  472  User_472   53    Male  Bangalore  149478      Sales
# ..   ...       ...  ...     ...        ...     ...        ...
# 248  249  User_249   57    Male       Pune   21591         IT
# 329  330  User_330   36    Male  Bangalore   21435      Sales
# 319  320  User_320   44    Male  Ahmedabad   21007    Finance
# 131  132  User_132   64    Male  Ahmedabad   20806  Marketing
# 467  468  User_468   43    Male  Bangalore   20526  Marketing
#
#      Experience_Years   Join_Date  Performance_Score  Bonus  \
# 113              19.1  2018-04-24                  2   6355
# 265               2.3  2018-09-23                  5   8186
# ...

# %%
df.iloc[0] # Select first row
# Out:
# ID                             1
# Name                      User_1
# Age                           56
# Gender                      Male
# City                   Ahmedabad
# Salary                     76276
# Department               Finance
# Experience_Years            12.2
# Join_Date             2018-01-01
# Performance_Score              1
# Bonus                       3092
# Projects_Completed            17
# Remote_Work                  Yes
# Training_Hours                54
# Promoted                     Yes
# Name: 0, dtype: object

# %%
df.iloc[5:11] # Select rows
# Out:
#     ID     Name  Age  Gender       City  Salary Department  Experience_Years  \
# 5    6   User_6   38  Female  Bangalore   57198         IT              17.1
# 6    7   User_7   56    Male  Ahmedabad   28820    Finance               4.6
# 7    8   User_8   36    Male  Ahmedabad   44070    Finance              18.6
# 8    9   User_9   40    Male      Delhi   89768         IT               2.8
# 9   10  User_10   28  Female       Pune   31122         IT              16.4
# 10  11  User_11   28  Female  Bangalore  100559      Sales               7.9
#
#      Join_Date  Performance_Score  Bonus  Projects_Completed Remote_Work  \
# 5   2018-01-06                  3  16271                  11         Yes
# 6   2018-01-07                  3   6776                  10         Yes
# 7   2018-01-08                  1  13449                   4         Yes
# 8   2018-01-09                  4   8823                  26          No
# ...

# %%
df["Bonus"].mean() # Mean
# Out:
# np.float64(10496.266)

# %%
df["Experience_Years"].max() # Max
# Out:
# 20.0

# %%
df[(df["Salary"]>50000) & (df["City"]=="Ahmedabad")] # Where condition
# Out:
#       ID      Name  Age  Gender       City  Salary Department  \
# 0      1    User_1   56    Male  Ahmedabad   76276    Finance
# 3      4    User_4   60    Male  Ahmedabad  102310         IT
# 26    27   User_27   39  Female  Ahmedabad  107312      Sales
# 30    31   User_31   59  Female  Ahmedabad  141826         HR
# 31    32   User_32   45  Female  Ahmedabad   55435         HR
# ..   ...       ...  ...     ...        ...     ...        ...
# 481  482  User_482   27  Female  Ahmedabad  141787      Sales
# 482  483  User_483   36    Male  Ahmedabad  149749         HR
# 486  487  User_487   62    Male  Ahmedabad  120737         HR
# 488  489  User_489   33  Female  Ahmedabad  102503         HR
# 494  495  User_495   44    Male  Ahmedabad  146740         IT
#
#      Experience_Years   Join_Date  Performance_Score  Bonus  \
# 0                12.2  2018-01-01                  1   3092
# 3                10.2  2018-01-04                  4   9549
# ...

# %%
df.groupby("Department")["Salary"].max() # Highest salary per department
# Out:
# Department
# Finance      149972
# HR           149749
# IT           147706
# Marketing    149839
# Sales        149478
# Name: Salary, dtype: int64

# %%
df["Annual_Salary"]=df["Salary"]*12 #Add new column Annual Salary
# Out:
#       ID      Name  Age  Gender       City  Salary Department  \
# 0      1    User_1   56    Male  Ahmedabad   76276    Finance
# 1      2    User_2   46    Male      Delhi   39541  Marketing
# 2      3    User_3   32    Male       Pune  114457         IT
# 3      4    User_4   60    Male  Ahmedabad  102310         IT
# 4      5    User_5   25    Male     Mumbai   64813      Sales
# ..   ...       ...  ...     ...        ...     ...        ...
# 495  496  User_496   37    Male       Pune  143153         IT
# 496  497  User_497   41    Male     Mumbai   46589    Finance
# 497  498  User_498   29  Female     Mumbai   50015    Finance
# 498  499  User_499   52    Male  Ahmedabad   49009      Sales
# 499  500  User_500   50    Male     Mumbai  103309         HR
#
#      Experience_Years   Join_Date  Performance_Score  Bonus  \
# 0                12.2  2018-01-01                  1   3092
# 1                10.6  2018-01-02                  1  19514
# ...

# %%
df["Year"]=df["Join_Date"].dt.year
df
# Out:
#       ID      Name  Age  Gender       City  Salary Department  \
# 0      1    User_1   56    Male  Ahmedabad   76276    Finance
# 1      2    User_2   46    Male      Delhi   39541  Marketing
# 2      3    User_3   32    Male       Pune  114457         IT
# 3      4    User_4   60    Male  Ahmedabad  102310         IT
# 4      5    User_5   25    Male     Mumbai   64813      Sales
# ..   ...       ...  ...     ...        ...     ...        ...
# 495  496  User_496   37    Male       Pune  143153         IT
# 496  497  User_497   41    Male     Mumbai   46589    Finance
# 497  498  User_498   29  Female     Mumbai   50015    Finance
# 498  499  User_499   52    Male  Ahmedabad   49009      Sales
# 499  500  User_500   50    Male     Mumbai  103309         HR
#
#      Experience_Years  Join_Date  Performance_Score  Bonus  \
# 0                12.2 2018-01-01                  1   3092
# 1                10.6 2018-01-02                  1  19514
# ...

# %%
df.corr(numeric_only=True) #Correlation matrix
# Out:
#                           ID       Age    Salary  Experience_Years  \
# ID                  1.000000  0.017480  0.008774          0.011774
# Age                 0.017480  1.000000 -0.049076         -0.022430
# Salary              0.008774 -0.049076  1.000000         -0.040035
# Experience_Years    0.011774 -0.022430 -0.040035          1.000000
# Performance_Score   0.029628  0.011185 -0.056329          0.032570
# Bonus              -0.048845 -0.037045 -0.004461         -0.038738
# Projects_Completed  0.057185 -0.002942  0.065154          0.029976
# Training_Hours     -0.076286  0.000013 -0.041411         -0.013671
# Annual_Salary       0.008774 -0.049076  1.000000         -0.040035
# Year                0.768962 -0.007251 -0.029035          0.030678
#
#                     Performance_Score     Bonus  Projects_Completed  \
# ID                           0.029628 -0.048845            0.057185
# Age                          0.011185 -0.037045           -0.002942
# ...
